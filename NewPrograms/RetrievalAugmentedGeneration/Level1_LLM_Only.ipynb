# %%
# ============================================================
# LEVEL 1: SIMPLE LLM-ONLY APPLICATION
# Gemini + Python
# No RAG
# No Vector Database
# No External Tools
# ============================================================

# !pip install -q google-genai

from google import genai
from google.colab import userdata

# %%
# ------------------------------------------------------------
# 1. Read Gemini API key from Colab Secrets
# ------------------------------------------------------------

import os
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)
os.environ["GOOGLE_API_KEY"] = api_key
#import os
#from getpass import getpass

#os.environ["GOOGLE_API_KEY"] = getpass("Enter Gemini API key: ")

# %%
# ------------------------------------------------------------
# 2. Ask user a question
# ------------------------------------------------------------

question = input("Enter your question: ")

# ------------------------------------------------------------
# 3. Send question directly to Gemini
# ------------------------------------------------------------

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents=question
)

# ------------------------------------------------------------
# 4. Display answer
# ------------------------------------------------------------

print("\nGemini Answer:")
print("=" * 50)
print(response.text)
# Out:
# Enter your question: PM Modi
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_5042/4278490614.py in <cell line: 0>()
#       9 # ------------------------------------------------------------
#      10
# ---> 11 response = client.models.generate_content(
#      12     model="gemini-2.5-flash",
#      13     contents=question
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    6547         )
#    6548       i += 1
# -> 6549       response = self._generate_content(
#    6550           model=model, contents=contents, config=parsed_config_to_call
#    6551       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4975     request_dict = _common.encode_unserializable_types(request_dict)
#    4976
# ...
